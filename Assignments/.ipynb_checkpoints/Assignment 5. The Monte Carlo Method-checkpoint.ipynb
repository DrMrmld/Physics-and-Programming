# %% [markdown]
# In this assignment we will implement a simple monte carlo method to calculate the value of $\pi$. Obviously we already know the value of $\pi$, but this exercise serves as a nice demonstation. We will draw a unit square, and draw inside it a quarter-circle with radius $r=1$. We will randomly select many points in the unit square (a random point can be selected by choosing a random number between 0 and 1 for the x value, and another random number between 0 and 1 for the y value).
#
# We know that the area of the square is $A_sq = 1$, and the area of the semicircle is $A_sc = \frac{\pi}{4}$ [^1]. Hence the probability of a randomly selected point falling inside the semicircle is $p = \frac{A_sc}{A_sq} = \frac{\frac{\pi}{4}}{1} = \frac{\pi}{4}$. Therefore we can find $\pi$ from this probability: $\pi = 4p$. On the other hand, in a simulation we can choose many points, and compute the probability $p$ as the empirical probability, $p=\frac{\textrm{number of points inside semircle}}{\textrm{total number of points}}$.
#
# Let's see how this works in practice.
#
# [^1]: (Area of a circle is $A = \pi r^2$, so area of a quarter-circle is $A = \frac{\pi r^2}{4}$. The radius of our quarter-circle is 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import chart_studio.plotly as py
import cufflinks as cf
import plotly.graph_objects as go
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %% [markdown]
# In the cell below we just plot the quarter-circle. This will be helpful later in visualising our results.

# %%
thetas = np.linspace(0, np.pi/2, 1000)
xs = np.cos(thetas)
ys = np.sin(thetas)

plt.plot(xs, ys)
plt.xlim([0, 1])
plt.ylim([0, 1])
ax = plt.gca()
ax.set_aspect('equal')

# %% [markdown]
# We know that we will need random numbers, so let's check the documentation.

# %%
help(np.random)

# %% [markdown]
# And here's the function that we nned to use. As you can see, it generates uniformly-distributed random numbers in the interval $[0, 1)$.

# %%
help(np.random.random)

# %% [markdown]
# Let's just check how it works. If we call np.random.random(), we'll get a random number. If we call np.random.random(3), we'll get an array of 3 random numbers. Run the cell below and observe that the numbers change each time.

# %%
print(np.random.random())
print(np.random.random(3))

# %% [markdown]
# Now let's pick some random points and plot them alongside the quarter-circle

# %%
n_points = 1000
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)

plt.plot(xs, ys, xSample, ySample, '.')
plt.xlim([0, 1])
plt.ylim([0, 1])
ax = plt.gca()
ax.set_aspect('equal')

# %% [markdown]
# Now we have to decide which points have fallen inside the quarter circle. This is very easy - a point is inside the circle if $x^2+y^2 <1$, keeping in mind that the radius of the circle is 1. As you can see, "accepted" is an array of boolean values that records whether each point was inside the quarter-circle.

# %%
n_points = 10
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

print(accepted)
# Out:
# [ True  True  True  True False  True  True  True  True False]

# %% [markdown]
# Let's now plot the points and circle. If you're confused by `xSample[accepted]`, you should review [array indexing in numpy](https://numpy.org/devdocs/reference/arrays.indexing.html)

# %%
n_points = 1000
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

# plt.plot(xs, ys,'k', xSample[accepted], ySample[accepted], 'b.', xSample[rejected], ySample[rejected], 'r.',)
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# ax = plt.gca()
# ax.set_aspect('equal')
# plt.legend(('boundary', 'accepted', 'rejected'))
# plt.show()

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(width=600, height=600, font=dict(family="CMU Serif", size=16), template="plotly_dark")
fig.show()
# Out:
# <div>                            <div id="ccdc5e52-3aaf-4e9a-aa9c-42be051e1c55" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccdc5e52-3aaf-4e9a-aa9c-42be051e1c55")) {                    Plotly.newPlot(                        "ccdc5e52-3aaf-4e9a-aa9c-42be051e1c55",                        [{"name":"Boundary","x":[1.0,0.9999987638285974,0.9999950553174459,0.999988874475714,0.9999802213186832,0.9999690958677468,0.999955498150411,0.9999394282002937,0.9999208860571255,0.9998998717667489,0.9998763853811183,0.9998504269583004,0.9998219965624732,0.9997910942639262,0.9997577201390606,0.9997218742703887,0.9996835567465339,0.9996427676622299,0.9995995071183217,0.9995537752217638,0.9995055720856215,0.9994548978290693,0.9994017525773913,0.9993461364619809,0.9
# ...

# %% [markdown]
# Now we need to find the empirical probability of a point falling inside the quarter-circle, $p=\frac{\textrm{number of points inside semircle}}{\textrm{total number of points}}$. It's easy to count the number of points inside the circle - `accepted` is an array of boolean values, so `accepted.sum()` will give us the number of `True` values in this array (`True` is treated as 1, and `False` is treated as 0).
#
# Run the code below with increasing values of `n_points` and observe how the computed value of $\pi$ becomes more accurate.

# %%
n_points = 50
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

# plt.plot(xs, ys, xSample[accepted], ySample[accepted], 'b.', xSample[rejected], ySample[rejected], 'r.',)
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# ax = plt.gca()
# ax.set_aspect('equal')

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(width=600, height=600)
fig.show()

# P(accept) = pi*r^2/4
# pi = 2 * sqrt(P(accept))
pAccept = accepted.sum() / n_points

pi_guess = 4*pAccept


print("Pi: Guess: %.4f, True: %.4f, percentage error: %.2f %% (n=%.f) " % (pi_guess, np.pi, 100*abs(np.pi-pi_guess)/np.pi, n_points))


n_points = 200
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(width=600, height=600)
fig.show()

pAccept = accepted.sum() / n_points

pi_guess = 4*pAccept


print("Pi: Guess: %.4f, True: %.4f, percentage error: %.2f %% (n=%.f) " % (pi_guess, np.pi, 100*abs(np.pi-pi_guess)/np.pi, n_points))



n_points = 1000
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(width=600, height=600)
fig.show()

pAccept = accepted.sum() / n_points

pi_guess = 4*pAccept


print("Pi: Guess: %.4f, True: %.4f, percentage error: %.2f %% (n=%.f) " % (pi_guess, np.pi, 100*abs(np.pi-pi_guess)/np.pi, n_points))



n_points = 10000
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(width=600, height=600)
fig.show()

pAccept = accepted.sum() / n_points

pi_guess = 4*pAccept


print("Pi: Guess: %.4f, True: %.4f, percentage error: %.2f %% (n=%.f) " % (pi_guess, np.pi, 100*abs(np.pi-pi_guess)/np.pi, n_points))
# Out:
# <div>                            <div id="16bf6e0d-11be-434b-be91-8bd38b3185b0" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16bf6e0d-11be-434b-be91-8bd38b3185b0")) {                    Plotly.newPlot(                        "16bf6e0d-11be-434b-be91-8bd38b3185b0",                        [{"name": "Boundary", "type": "scatter", "x": [1.0, 0.9999987638285974, 0.9999950553174459, 0.999988874475714, 0.9999802213186832, 0.9999690958677468, 0.999955498150411, 0.9999394282002937, 0.9999208860571255, 0.9998998717667489, 0.9998763853811183, 0.9998504269583004, 0.9998219965624732, 0.9997910942639262, 0.9997577201390606, 0.9997218742703887, 0.9996835567465339, 0.9996427676622299, 0.9995995071183217, 0.9995537752217638, 0.9995055720856215, 0.999454897829069
# ...

# %% [markdown]
# Once important point about monte-carlo methods. Since we are computing a probability based on random samples, there is an inherent uncertainty - if we used fewer points, then we would be less certain about our calculated value of $\pi$. Statistics tells us that if we used $N$ points, and calculate a true probability $\hat{p}$, then there is a 95% chance that the *true* value of $p$ is between  $ p - 1.96 \sqrt{\frac{p (1 - p)}{N}}$ and  $ p + 1.96 \sqrt{\frac{p (1 - p)}{N}}$. If you want to understand why, you can read [this page](https://openstax.org/books/introductory-business-statistics/pages/8-3-a-confidence-interval-for-a-population-proportion). It makes sense to say that the uncertainty in the value of $p$ is $\Delta p = 1.96 \sqrt{\frac{p (1 - p)}{N}}$. The uncertainty in our value of $\pi_{\textrm{calc}}$ is therefore $\Delta \pi_{\textrm{calc}} = 4 \Delta p$. Let's calculate these and see if our code achieves the expected accuracy.
#
# Run the code below and compare the actual error to the theoretical error. For low values of `n_points`, they can be quite different, but when `n_points` is large, they converge. Notice that as you increase `n_points`, the theoretical error decreases. The theoretical estimate of the error allows us to be precise about the error in our calculated values.

# %%
n_points = 100
xSample = np.random.random(n_points)
ySample = np.random.random(n_points)
accepted = (xSample**2 + ySample**2 ) < 1
rejected = (xSample**2 + ySample**2 ) >= 1

# plt.plot(xs, ys, xSample[accepted], ySample[accepted], 'b.', xSample[rejected], ySample[rejected], 'r.',)
# plt.xlim([0, 1])
# plt.ylim([0, 1])
# ax = plt.gca()
# ax.set_aspect('equal')

fig = go.Figure()
fig.add_trace(go.Scatter(name="Boundary", x=xs, y=ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode="markers"))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode="markers"))
fig.update_layout(width=600, height=600, font=dict(family="CMU Serif", size=16))
fig.show()

# P(accept) = pi*r^2/4
# pi = 2 * sqrt(P(accept))
pAccept = accepted.sum() / n_points

pi_guess = 4*pAccept
pAccept_error = (1.96)*np.sqrt(pAccept*(1-pAccept)/n_points)
pi_guess_error = 4*pAccept_error

print("Pi: Guess: %.4f, True: %.4f, percentage error (vs calculated): %.2f %%, percentage error (theoretical): %.2f %%"\
      % (pi_guess, np.pi, 100*abs(np.pi-pi_guess)/np.pi, 100*0.5*pi_guess_error/np.pi))



n_points_range = np.arange(100, 1000, 100)
pi_est_range = []
pi_est_error_range = []

for i in n_points_range:
    xSample = np.random.random(i)
    ySample = np.random.random(i)
    accepted = (xSample**2 + ySample**2 ) < 1
    rejected = (xSample**2 + ySample**2 ) >= 1
    
    p_est = accepted.sum() / i
    pi_est = 4 * p_est
    pi_est_range.append(pi_est)
    
    p_est_error = (1.96)*np.sqrt(p_est*(1-p_est)/i)
    pi_est_error = 4*p_est_error
    pi_est_error_range.append(pi_est_error)

pi_values = [np.pi] * len(pi_est_range)
    
fig = go.Figure()
fig.add_trace(go.Scatter(name="Estimation", x=n_points_range, y=pi_est_range))
fig.add_trace(go.Scatter(name="Error", x=n_points_range, y=pi_est_error_range))
fig.add_trace(go.Scatter(name="True value", x=n_points_range, y=pi_values))
fig.update_layout(title="Estimation and error dependence from n", font=dict(family="CMU Serif", size=16))
fig.show()


n_points_range = np.arange(1000, 10000, 100)
pi_est_range = []
pi_est_error_range = []

for i in n_points_range:
    xSample = np.random.random(i)
    ySample = np.random.random(i)
    accepted = (xSample**2 + ySample**2 ) < 1
    rejected = (xSample**2 + ySample**2 ) >= 1
    
    p_est = accepted.sum() / i
    pi_est = 4 * p_est
    pi_est_range.append(pi_est)
    
    p_est_error = (1.96)*np.sqrt(p_est*(1-p_est)/i)
    pi_est_error = 4*p_est_error
    pi_est_error_range.append(pi_est_error)

pi_values = [np.pi] * len(pi_est_range)
    
fig = go.Figure()
fig.add_trace(go.Scatter(name="Estimation", x=n_points_range, y=pi_est_range))
fig.add_trace(go.Scatter(name="Error", x=n_points_range, y=pi_est_error_range))
fig.add_trace(go.Scatter(name="True value", x=n_points_range, y=pi_values))
fig.update_layout(title="Estimation and error dependence from n", font=dict(family="CMU Serif", size=16))
fig.show()
# Out:
# <div>                            <div id="fdf4ac1e-093d-4a91-b29c-77f9f1b357e0" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdf4ac1e-093d-4a91-b29c-77f9f1b357e0")) {                    Plotly.newPlot(                        "fdf4ac1e-093d-4a91-b29c-77f9f1b357e0",                        [{"name": "Boundary", "type": "scatter", "x": [1.0, 0.9999987638285974, 0.9999950553174459, 0.999988874475714, 0.9999802213186832, 0.9999690958677468, 0.999955498150411, 0.9999394282002937, 0.9999208860571255, 0.9998998717667489, 0.9998763853811183, 0.9998504269583004, 0.9998219965624732, 0.9997910942639262, 0.9997577201390606, 0.9997218742703887, 0.9996835567465339, 0.9996427676622299, 0.9995995071183217, 0.9995537752217638, 0.9995055720856215, 0.999454897829069
# ...

# %% [markdown]
# # Tasks
# 1. Adapt my code above to investigate how the calculated value of $\pi$ varies with the number of points. Make a graph of $\pi_{\textrm{calc}}$ against `n_points`. Add to this graph a horizontal line showing the true value of $\pi$, and also plot $\pi_{\textrm{calc}} - \Delta \pi_\textrm{calc}$,  and $\pi_{\textrm{calc}} + \Delta \pi_\textrm{calc}$.
# 2. The error function is defined as $\operatorname{erf(z)} = \frac{2}{\sqrt{\pi}} \int^{z}_{0} e^{-t^2} dt$. That is, $\frac{2}{\sqrt{\pi}}$ multiplied by the area under the curve $y = e^{-t^2}$ between $t=0$ and $t=z$. This area can be computed using a monte-carlo method. Use such a method to write code to estimate a) $\operatorname{erf}(1)$, b) $\operatorname{erf}(2)$. You can check your answers using [this tool](https://keisan.casio.com/exec/system/1180573449).
#
# *Hint*. First realise that the curve $y=e^{-t^2}$ has a max value of $1$ at $t=0$ (see graph [here](https://www.wolframalpha.com/input/?i=plot%28e%5E-t%5E2%29). Consider a rectangle with one corner at $(0,0)$ and the opposite corner at $(z, 1)$. That is a rectangle with width $z$ and height 1. This rectangle's area is equal to $z$. Now randomly choose points in this rectange, and check if they fall underneath the curve $y=e^{-t^2}$. In this case, the probability of a point falling under the curve is $p = \frac{\textrm{area under the curve } y = e^{-t^2} \textrm{ between } t=0 \textrm{ and } t=z}{\textrm{area of rectangle}} = \frac{\int^{z}_{0} e^{-t^2} dt}{z}$, so from the probability, we can calculate $\int^{z}_{0} e^{-t^2} dt$ and then $\operatorname{erf}(z)$
#
# 3. Extend the code from 2. to create a function that computes $\operatorname{erf}(z)$ for *any* value of $z$.
# 4. Extend the code from 3. to add a feature to the function that allows the user to specify the *maximum* allowed percentage uncertainty in the calculated value of $\operatorname{erf}(z)$. (this will involve changing the number of

# %%
# Task 1

n_points_range = np.arange(100, 5000, 100)
pi_est_range = []
pi_est_error_range = []

for i in n_points_range:
    xSample = np.random.random(i)
    ySample = np.random.random(i)
    accepted = (xSample**2 + ySample**2 ) < 1
    rejected = (xSample**2 + ySample**2 ) >= 1
    
    p_est = accepted.sum() / i
    pi_est = 4 * p_est
    pi_est_range.append(pi_est)
    
    p_est_error = (1.96)*np.sqrt(p_est*(1-p_est)/i)
    pi_est_error = 4*p_est_error
    pi_est_error_range.append(pi_est_error)

pi_values = [np.pi] * len(pi_est_range)
pi_est_upper = []
pi_est_lower = []

for i in range(len(n_points_range)):
    pi_est_upper.append(pi_est_range[i] + pi_est_error_range[i])
    pi_est_lower.append(pi_est_range[i] - pi_est_error_range[i])
    
fig = go.Figure()
fig.add_trace(go.Scatter(name="Estimation", x=n_points_range, y=pi_est_range))
fig.add_trace(go.Scatter(name="Error", x=n_points_range, y=pi_est_error_range))
fig.add_trace(go.Scatter(name="True value", x=n_points_range, y=pi_values))
fig.add_trace(go.Scatter(name="Upper limit of estimation", x=n_points_range, y=pi_est_upper))
fig.add_trace(go.Scatter(name="Lower limit of estimation", x=n_points_range, y=pi_est_lower))
fig.update_layout(title="Estimation and error dependence from n", font=dict(family="CMU Serif", size=16), template="plotly_dark")
fig.show()
# Out:
# <div>                            <div id="c6c62fb0-5139-412f-8581-91ade4e10d94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6c62fb0-5139-412f-8581-91ade4e10d94")) {                    Plotly.newPlot(                        "c6c62fb0-5139-412f-8581-91ade4e10d94",                        [{"name": "Estimation", "type": "scatter", "x": [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900], "y": [3.32, 2.98, 3.28, 3.12, 3.0, 3.1266666666666665, 3.1142857142857143, 3.19, 3.2177777777777776, 3.084, 3.1454545454545455, 3.146
# ...

# %%
# Task 2

import scipy.special as spec

end_point = 3
exp_xs = np.linspace(0, end_point, 1000)
exp_ys = np.exp(-exp_xs**2)

z = 2
vert_ys = np.linspace(0, 1, 1000)
vert_xs = [z] * 1000

hor_xs = np.linspace(0, z, 1000)
hor_ys = [1] * 1000

n_points = 1000
xSample = np.random.random(n_points) * z
ySample = np.random.random(n_points)
accepted = ySample < np.exp(-xSample**2)
rejected = ySample >= np.exp(-xSample**2)

p_est = accepted.sum() / n_points
area = p_est * z
erf = (2/np.sqrt(np.pi)) * area

fig = go.Figure()
fig.add_trace(go.Scatter(name="e^(-x^2)", x=exp_xs, y=exp_ys))
fig.add_trace(go.Scatter(name="Vertical boundary", x=vert_xs, y=vert_ys))
fig.add_trace(go.Scatter(name="Horizontal boundary", x=hor_xs, y=hor_ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(title="Estimation of erf for z=1 and z=2", font=dict(family="CMU Serif", size=16))
fig.show()

print("Estimation of erf(" + str(z) + ")=" + str(erf))
print("Real value of erf(" + str(z) + ")=" + str(spec.erf(z)))
# Out:
# <div>                            <div id="f3d33cff-865e-4cef-965e-a30b12978cf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3d33cff-865e-4cef-965e-a30b12978cf1")) {                    Plotly.newPlot(                        "f3d33cff-865e-4cef-965e-a30b12978cf1",                        [{"name": "e^(-x^2)", "type": "scatter", "x": [0.0, 0.003003003003003003, 0.006006006006006006, 0.009009009009009009, 0.012012012012012012, 0.015015015015015015, 0.018018018018018018, 0.02102102102102102, 0.024024024024024024, 0.02702702702702703, 0.03003003003003003, 0.03303303303303303, 0.036036036036036036, 0.03903903903903904, 0.04204204204204204, 0.04504504504504504, 0.04804804804804805, 0.05105105105105105, 0.05405405405405406, 0.057057057057057055, 0.060060
# ...

# %%
# Task 3

import scipy.special as spec

z = 3

end_point = z+1
exp_xs = np.linspace(0, end_point, 2000)
exp_ys = np.exp(-exp_xs**2)

vert_ys = np.linspace(0, 1, 2000)
vert_xs = [z] * 2000

hor_xs = np.linspace(0, z, 2000)
hor_ys = [1] * 2000

n_points = 1500
xSample = np.random.random(n_points) * z
ySample = np.random.random(n_points)
accepted = ySample < np.exp(-xSample**2)
rejected = ySample >= np.exp(-xSample**2)

p_est = accepted.sum() / n_points
area = p_est * z
erf = (2/np.sqrt(np.pi)) * area

fig = go.Figure()
fig.add_trace(go.Scatter(name="e^(-x^2)", x=exp_xs, y=exp_ys))
fig.add_trace(go.Scatter(name="Vertical boundary", x=vert_xs, y=vert_ys))
fig.add_trace(go.Scatter(name="Horizontal boundary", x=hor_xs, y=hor_ys))
fig.add_trace(go.Scatter(name="Accepted", x=xSample[accepted], y=ySample[accepted], mode='markers'))
fig.add_trace(go.Scatter(name="Rejected", x=xSample[rejected], y=ySample[rejected], mode='markers'))
fig.update_layout(title="Estimation of erf for any value of z", font=dict(family="CMU Serif", size=16))
fig.show()

print("Estimation of erf(" + str(z) + ")=" + str(erf))
print("Real value of erf(" + str(z) + ")=" + str(spec.erf(z)))
# Out:
# <div>                            <div id="729994bc-b65e-4944-afc9-79b02dbb4a1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("729994bc-b65e-4944-afc9-79b02dbb4a1a")) {                    Plotly.newPlot(                        "729994bc-b65e-4944-afc9-79b02dbb4a1a",                        [{"name": "e^(-x^2)", "type": "scatter", "x": [0.0, 0.002001000500250125, 0.00400200100050025, 0.006003001500750374, 0.0080040020010005, 0.010005002501250625, 0.012006003001500749, 0.014007003501750874, 0.016008004002001, 0.018009004502251125, 0.02001000500250125, 0.022011005502751375, 0.024012006003001497, 0.026013006503251623, 0.028014007003501748, 0.030015007503751873, 0.032016008004002, 0.03401700850425212, 0.03601800900450225, 0.03801900950475237, 0.040020010
# ...

# %%
# Task 4

import scipy.special as spec

z = 3
uncertainty = 7 # type the wanted percentage of the uncertainty here
uncertainty /= 100

end_point = z+1
exp_xs = np.linspace(0, end_point, 2000)
exp_ys = np.exp(-exp_xs**2)

vert_ys = np.linspace(0, 1, 2000)
vert_xs = [z] * 2000

hor_xs = np.linspace(0, z, 2000)
hor_ys = [1] * 2000

n_points = 10
answer_arr = [0, 0, 0] # a list that will store the answers

def estimateErf(n_points, z, uncertainty):
    xSample = np.random.random(n_points) * z
    ySample = np.random.random(n_points)
    accepted = ySample < np.exp(-xSample**2)
    rejected = ySample >= np.exp(-xSample**2)

    p_est = accepted.sum() / n_points
    area = p_est * z
    erf = (2/np.sqrt(np.pi)) * area

    standard_error = np.sqrt(p_est * (1-p_est) / n_points)
    exp_uncertainty = 1.96 * standard_error / erf
    
    if (exp_uncertainty > uncertainty):
        n_points *= 10
        print(str(round(exp_uncertainty*100, 2)) + "% > " + str(round(uncertainty*100, 2)) + "%\nIncreasing points number to " + str(n_points) + "\n")
        return estimateErf(n_points, z, uncertainty)
    
    fig = go.Figure()
    fig.add_trace(go.Scatter(name="e^(-x^2)", x=exp_xs, y=exp_ys))
    fig.add_trace(go.Scatter(name="Vertical boundary", x=vert_xs, y=vert_ys))
    fig.add_trace(go.Scatter(name="Horizontal boundary", x=hor_xs, y=hor_ys))
    fig.add_trace(go.Scatter(name="Accepted points", x=xSample[accepted], y=ySample[accepted], mode='markers'))
    fig.add_trace(go.Scatter(name="Rejected points", x=xSample[rejected], y=ySample[rejected], mode='markers'))
    fig.update_layout(title="Estimation of erf with fixed maximum uncertainty", font=dict(family="CMU Serif", size=16), template="plotly_dark")
    fig.show()
    
    return [erf, standard_error, exp_uncertainty]
    
answer_arr = estimateErf(n_points, z, uncertainty)
erf = answer_arr[0]
standard_error = answer_arr[1]
exp_uncertainty = answer_arr[2]

print("Estimation of erf(" + str(z) + ")= " + str(round(erf, 3)) + " pm " + str(round(1.96 * standard_error, 3)))
print("Real value of erf(" + str(z) + ")= " + str(round(spec.erf(z), 3)))
print("Wanted uncertainty= " + str(round(uncertainty*100, 2)) + "%")
print("Experimental uncertainty= " + str(round(exp_uncertainty*100, 2)) + "%")
# Out:
# 54.93% > 7.0%
# Increasing points number to 100
#
# 9.52% > 7.0%
# Increasing points number to 1000
# ...
